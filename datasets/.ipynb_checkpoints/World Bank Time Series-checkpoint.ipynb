# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sbs

df = pd.read_csv('./wordBank.csv')
df.head()
# Out:
#    Unnamed: 0  Time Time Code    Country Name Country Code  Population, total  \
# 0           0  2000    YR2000     Afghanistan          AFG         20779953.0
# 1           1  2000    YR2000         Albania          ALB          3089027.0
# 2           2  2000    YR2000         Algeria          DZA         31042235.0
# 3           3  2000    YR2000  American Samoa          ASM            57821.0
# 4           4  2000    YR2000         Andorra          AND            65390.0
#
#    Population growth (annual %)  Surface area (sq. km)  \
# 0                      2.975053               652860.0
# 1                     -0.637357                28750.0
# 2                      1.358408              2381740.0
# 3                      1.337137                  200.0
# 4                      1.572166                  470.0
#
#    Poverty headcount ratio at national poverty lines (% of population)  \
# 0                                                NaN
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  Time Time Code  \
# 4315        4730  2017    YR2017
# 4316        4733  2017    YR2017
# 4317        4734  2017    YR2017
# 4318        4735  2017    YR2017
# 4319        4741  2017    YR2017
#
#                                            Country Name Country Code  \
# 4315                                Low & middle income          LMY
# 4316                         Middle East & North Africa          MEA
# 4317  Middle East & North Africa (excluding high inc...          MNA
# 4318  Middle East & North Africa (IDA & IBRD countries)          TMN
# 4319                        Pacific island small states          PSS
#
#       Population, total  Population growth (annual %)  Surface area (sq. km)  \
# 4315       6.306561e+09                      1.265433           9.480824e+07
# 4316       4.412552e+08                      1.766063           1.137062e+07
# 4317       3.765468e+08                      1.693409           8.775232e+06
# ...

# %%
df.tail()

# %%
df.to_csv('worldBank.csv')
