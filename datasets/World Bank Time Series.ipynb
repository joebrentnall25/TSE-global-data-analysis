# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sbs

df = pd.read_csv('./worldBank.csv', index_col = 0)
df.head()
# Out:
#           Country Code  Population, total  Population growth (annual %)  \
# Time Code
# YR2000             AFG         20779953.0                      2.975053
# YR2000             ALB          3089027.0                     -0.637357
# YR2000             DZA         31042235.0                      1.358408
# YR2000             ASM            57821.0                      1.337137
# YR2000             AND            65390.0                      1.572166
#
#            Surface area (sq. km)  \
# Time Code
# YR2000                  652860.0
# YR2000                   28750.0
# YR2000                 2381740.0
# YR2000                     200.0
# YR2000                     470.0
#
#            Poverty headcount ratio at national poverty lines (% of population)  \
# Time Code
# YR2000                                                   NaN
# YR2000                                                   NaN
# YR2000                                                   NaN
# ...

# %%
df.isnull().sum()
# Out:
# Country Code                                                              0
# Population, total                                                         6
# Population growth (annual %)                                              6
# Surface area (sq. km)                                                    36
# Poverty headcount ratio at national poverty lines (% of population)    3182
#                                                                        ...
# Number of maternal deaths                                               576
# Number of neonatal deaths                                               432
# Patent applications, nonresidents                                      1994
# Patent applications, residents                                         2103
# People practicing open defecation (% of population)                     195
# Length: 62, dtype: int64
